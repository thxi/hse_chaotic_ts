# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Lorenz" data-toc-modified-id="Lorenz-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Lorenz</a></span><ul class="toc-item"><li><span><a href="#Heal" data-toc-modified-id="Heal-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Heal</a></span><ul class="toc-item"><li><span><a href="#1" data-toc-modified-id="1-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>1</a></span></li><li><span><a href="#2" data-toc-modified-id="2-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>2</a></span></li><li><span><a href="#3" data-toc-modified-id="3-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>3</a></span></li></ul></li><li><span><a href="#Quantiles" data-toc-modified-id="Quantiles-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Quantiles</a></span></li></ul></li></ul></div>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()

from tqdm.auto import tqdm

import random

# %%
from sklearn.cluster import DBSCAN

from src.Lorentz import Lorentz
from src.TSProcessor import TSProcessor

# %load_ext autoreload
# %autoreload 2

# %%
from src.utils import normalize, denormalize, diag_plot

# %% [markdown]
# ## Lorenz

# %% [markdown]
# split into train and test
#
# train = 3/4 of data
# test = 1/4 of data

# %% [markdown]
# ### Heal

# %%
split = 10000

steps = 50
eps   = 0.01
n_trajectories = 10
noise_amp = 0.03

dbs_eps = 0.01
dbs_min_samples = 4

# %%
x, _, _ = Lorentz().generate(0.1, 3000+split+steps)
x, x_min, x_max = normalize(x[3000:]) # "For the Lorenz series, the first 3000 observations are discarded..."

# %%
X_train = x[:split]
X_test = x[split:split + steps]

# %%
fig = plt.figure(figsize=[6, 3])
plt.plot(X_train, label='train')
plt.plot(range(split, split+steps), X_test, label='test')

plt.title('Lorenz')

plt.vlines(split, 0, 1,
           color='orange', linestyle='dashed')

plt.legend();
fig.tight_layout()

# %% [markdown]
# #### 1

# %%
tsp = TSProcessor(4, 10)

# %%
tsp.fit(x[:split])

# %%
forecast_sets = tsp.pull(
    steps=steps,
    eps=eps,
    n_trajectories=n_trajectories,
    noise_amp=noise_amp,
    n_jobs=-1
)
# Out:
# 90.64s

# %%
# get a unified prediction at each point
result = tsp.cluster_sets(forecast_sets, dbs_eps, dbs_min_samples)
np.isnan(result).sum()
# Out:
# 38

# %%
non_pred = np.cumsum(np.isnan(result).astype(int))
pred = np.cumsum(1 - np.isnan(result).astype(int))
pred[pred == 0] = 1
rmse = np.cumsum(np.nan_to_num(np.sqrt((result - X_test)**2), nan=0)) /pred

# %%
diag_plot(
    X_train, X_test,
    split, steps, noise_amp, n_trajectories,
    forecast_sets, result, non_pred, rmse, filename='lorenz/heal_before.png')

# %% [markdown]
# #### 2

# %%
forecast_sets = tsp.pull(
    steps=steps,
    eps=eps,
    n_trajectories=n_trajectories,
    noise_amp=noise_amp,
    prev_result=result,
    random_seed=2,
    n_jobs=-1
)
# Out:
# 65.81s

# %%
# get a unified prediction at each point
new_result = tsp.cluster_sets(forecast_sets, dbs_eps, dbs_min_samples)
np.isnan(new_result).sum()
# Out:
# 29

# %%
result[np.isnan(result)] = new_result[np.isnan(result)]

# %%
non_pred = np.cumsum(np.isnan(result).astype(int))
pred = np.cumsum(1 - np.isnan(result).astype(int))
pred[pred == 0] = 1
rmse = np.cumsum(np.nan_to_num(np.sqrt((result - X_test)**2), nan=0)) /pred

# %%
diag_plot(
    X_train, X_test,
    split, steps, noise_amp, n_trajectories,
    forecast_sets, result, non_pred, rmse, filename='lorenz/heal_after1.png')

# %% [markdown]
# #### 3

# %%
forecast_sets = tsp.pull(
    steps=steps,
    eps=eps,
    n_trajectories=n_trajectories,
    noise_amp=noise_amp,
    prev_result=result,
    random_seed=3,
    n_jobs=-1
)
# Out:
# 57.78s

# %%
# get a unified prediction at each point
new_result = tsp.cluster_sets(forecast_sets, dbs_eps, dbs_min_samples)
np.isnan(new_result).sum()
# Out:
# 23

# %%
result[np.isnan(result)] = new_result[np.isnan(result)]

# %%
non_pred = np.cumsum(np.isnan(result).astype(int))
pred = np.cumsum(1 - np.isnan(result).astype(int))
pred[pred == 0] = 1
rmse = np.cumsum(np.nan_to_num(np.sqrt((result - X_test)**2), nan=0)) /pred

# %%
diag_plot(
    X_train, X_test,
    split, steps, noise_amp, n_trajectories,
    forecast_sets, result, non_pred, rmse, filename='lorenz/heal_after2.png')

# %% [markdown]
# ### Quantiles

# %%
split = 10000

steps = 50
eps   = 0.01
n_trajectories = 32
noise_amp = 0.03

dbs_eps = 0.01
dbs_min_samples = 4

# %%
x, _, _ = Lorentz().generate(0.1, 3000+split+steps)
x, x_min, x_max = normalize(x[3000:]) # "For the Lorenz series, the first 3000 observations are discarded..."

# %%
X_train = x[:split]
X_test = x[split:split + steps]

# %%
fig = plt.figure(figsize=[6, 3])
plt.plot(X_train, label='train')
plt.plot(range(split, split+steps), X_test, label='test')

plt.title('Lorenz')

plt.vlines(split, 0, 1,
           color='orange', linestyle='dashed')

plt.legend();
fig.tight_layout()

# %%
tsp = TSProcessor(4, 10)

# %%
tsp.fit(x[:split])

# %%
forecast_sets = tsp.pull(
    steps=steps,
    eps=eps,
    n_trajectories=n_trajectories,
    noise_amp=noise_amp,
    n_jobs=-1
)
# Out:
# 382.57s

# %%
# get a unified prediction at each point
result = tsp.get_quantile_prediction(forecast_sets, max_err=0.1, alpha=0.1)
np.isnan(result).sum()
# Out:
# 0 0.8631350483807675 0.9261490119970692 0.06301396361630174
# 1 0.7454317130783935 0.8201416524937056 0.07470993941531212
# 2 0.6015268464156505 0.6658538130432444 0.06432696662759396
# 3 0.5105651529517918 0.5927611500680668 0.08219599711627501
# 4 0.5128368101996444 0.5909371872569646 0.0781003770573202
# 5 0.5578010995635447 0.6467724435153674 0.08897134395182271
# 6 0.6665611680475613 0.7438869392270302 0.07732577117946893
# 7 0.7935599504712042 0.8819524657069306 0.08839251523572644
# 8 0.8128751112770077 0.8719114215826308 0.05903631030562306
# 9 0.6508505550252899 0.730658254891001 0.07980769986571112
# 10 0.5406514595018593 0.6101640963301902 0.06951263682833086
# 11 0.52380747520609 0.5932094011510006 0.06940192594491068
# 12 0.5137221055415442 0.597522106306626 0.08380000076508187
# 13 0.5256312523458829 0.6388821986293823 0.11325094628349941
# 14 0.6010479259974133 0.7753733953837902 0.17432546938637694
# 15 0.6754589310895591 0.8477649983829667 0.17230606729340758
# 16 0.7032793050883733 0.8226013620319914 0.11932205694361808
# 17 0.5954390835227793 0.729270323592315 0.13383124006953573
# 18 0.5123405797334754 0.619712693983931 0.10737211425045567
# 19 0.48178259504627613 0.5923558579186636 0.1105732628723875
# 20 0.4761324152424445 0.5711432148294582 0.0950107995870137
# 21 0.4186535844976197 0.6633082427626312 0.24465465826501154
# 22 0.45395188579250123 0.7293997991684722 0.27544791337597097
# 23 0.35827120953585384 0.79006002396206 0.43178881442620615
# 24 0.2679088783835204 0.7738517454482902 0.5059428670647698
# 25 0.3030160003205042 0.6687560624774543 0.36574006215695015
# 26 0.4014652242382778 0.6669160519906681 0.26545082775239026
# 27 0.4707536945273502 0.5733599085062202 0.10260621397886999
# 28 0.47372027470276606 0.6018808121083449 0.1281605374055788
# 29 0.4244930530233265 0.624027079969757 0.19953402694643052
# 30 0.3679661137301584 0.6722230101817219 0.3042568964515635
# 31 0.32923026130948047 0.7254409882125048 0.39621072690302434
# 32 0.2735185301082149 0.6822532198607596 0.4087346897525447
# 33 0.2611966122701697 0.6514870625853618 0.3902904503151921
# 34 0.3287172441059754 0.6510017321398582 0.3222844880338828
# 35 0.4007165537406974 0.5916202344053736 0.19090368066467617
# 36 0.4709507446649129 0.5962758452218493 0.1253251005569364
# 37 0.4383013773877815 0.6503224333238745 0.212021055936093
# 38 0.4023038176084715 0.6757603666730642 0.27345654906459266
# 39 0.40292386211865316 0.676509277043883 0.2735854149252298
# 40 0.3075788469290918 0.6634514684929483 0.3558726215638565
# 41 0.3030000361124246 0.6154760041322939 0.31247596801986927
# 42 0.3527674589977271 0.6098352553589005 0.2570677963611734
# 43 0.40835339897204503 0.618637898539522 0.21028449956747697
# 44 0.42126710637346554 0.6246489052184101 0.20338179884494456
# 45 0.4182617787546677 0.6218482818056075 0.20358650305093978
# 46 0.4117157271865201 0.6674647485583318 0.2557490213718117
# 47 0.42052639735261055 0.715097344084725 0.2945709467321145
# 48 0.34775596089468647 0.6334173862876283 0.28566142539294187
# 49 0.34210848786891734 0.6213306723732939 0.2792221845043765
# 36

# %%
non_pred = np.cumsum(np.isnan(result).astype(int))
pred = np.cumsum(1 - np.isnan(result).astype(int))
pred[pred == 0] = 1
rmse = np.cumsum(np.nan_to_num(np.sqrt((result - X_test)**2), nan=0)) /pred

# %%
diag_plot(
    X_train, X_test,
    split, steps, noise_amp, n_trajectories,
    forecast_sets, result, non_pred, rmse, filename=f'lorenz/quantile_pred_{n_trajectories}.png')
